# %%
import lmdb
env = lmdb.open(
    '/home/zhanghaonan/Video-Swin-Transformer-master/data/vis_db/msrvtt', readonly=True,
    create=False)  # readahead=not _check_distributed()
txn = env.begin(buffers=True)
for key, value in txn.cursor():  
    print (key, value)
# Out:
# <memory at 0x7f16f833d1f0> <memory at 0x7f16f833d2c0>
# <memory at 0x7f16e15ec600> <memory at 0x7f16e15ec6d0>
# <memory at 0x7f16f833d2c0> <memory at 0x7f16f833d1f0>
# <memory at 0x7f16e15ec6d0> <memory at 0x7f16e15ec600>
# <memory at 0x7f16f833d1f0> <memory at 0x7f16f833d2c0>
# <memory at 0x7f16e15ec600> <memory at 0x7f16e15ec7a0>
# <memory at 0x7f16f833d2c0> <memory at 0x7f16f833d1f0>
# <memory at 0x7f16e15ec7a0> <memory at 0x7f16e15ec6d0>
# <memory at 0x7f16f833d1f0> <memory at 0x7f16f833d2c0>
# <memory at 0x7f16e15ec6d0> <memory at 0x7f16e15ec7a0>
# <memory at 0x7f16f833d2c0> <memory at 0x7f16f833d1f0>
# <memory at 0x7f16e15ec7a0> <memory at 0x7f16e15ec6d0>
# <memory at 0x7f16f833d1f0> <memory at 0x7f16f833d2c0>
# <memory at 0x7f16e15ec6d0> <memory at 0x7f16e15ec7a0>
# <memory at 0x7f16f833d2c0> <memory at 0x7f16f833d1f0>
# <memory at 0x7f16e15ec7a0> <memory at 0x7f16e15ec6d0>
# <memory at 0x7f16f833d1f0> <memory at 0x7f16f833d2c0>
# ...
